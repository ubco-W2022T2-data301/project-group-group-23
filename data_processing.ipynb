# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
adv_st = pd.read_csv('data/raw/Advanced.csv')
player_tot = pd.read_csv('data/raw/Player Totals.csv')
player_shoot = pd.read_csv('data/raw/Player Shooting.csv')
player_pg = pd.read_csv('data/raw/Player Per Game.csv')
team_tot = pd.read_csv('data/raw/Team Totals.csv')

# %%
player_shoot = pd.read_csv('data/raw/Player Shooting.csv')
new_names = {
    'seas_id': 'season_id',
    'player_id': 'player_id',
    'player': 'player_name',
    'birth_year': 'birth_year',
    'pos': 'position',
    'experience': 'years_of_experience',
    'lg': 'league',
    'tm': 'team',
    'g': 'games_played',
    'mp': 'minutes_played',
    'fg_percent': 'field_goal_percentage',
    'avg_dist_fga': 'average_field_goal_attempt_distance',
    'percent_fga_from_x2p_range': 'percentage_of_field_goal_attempts_from_2_point_range',
    'percent_fga_from_x0_3_range': 'percentage_of_field_goal_attempts_from_0_to_3_feet',
    'percent_fga_from_x3_10_range': 'percentage_of_field_goal_attempts_from_3_to_10_feet',
    'percent_fga_from_x10_16_range': 'percentage_of_field_goal_attempts_from_10_to_16_feet',
    'percent_fga_from_x16_3p_range': 'percentage_of_field_goal_attempts_from_16_feet_to_3_point_range',
    'percent_fga_from_x3p_range': 'percentage_of_field_goal_attempts_from_3_point_range',
    'fg_percent_from_x2p_range': 'field_goal_percentage_from_2_point_range',
    'fg_percent_from_x0_3_range': 'field_goal_percentage_from_0_to_3_feet',
    'fg_percent_from_x3_10_range': 'field_goal_percentage_from_3_to_10_feet',
    'fg_percent_from_x10_16_range': 'field_goal_percentage_from_10_to_16_feet',
    'fg_percent_from_x16_3p_range': 'field_goal_percentage_from_16_feet_to_3_point_range',
    'fg_percent_from_x3p_range': 'three_point_percentage',
    'fga': 'field_goal_attempts',
    'fgm': 'field_goal_made',
    'x2p': 'two_pointers',
    'x2pa': 'two_point_attempts',
    'x2pm': 'two_point_made',
    'percent_assisted_x2p_fg': 'percent_assisted_two_point_field_goal',
    'percent_assisted_x3p_fg': 'percent_assisted_three_point_field_goal',
    'percent_dunks_of_fga': 'percent_of_dunks_in_field_goal_attempts',
    'num_of_dunks': 'number_of_dunks',
    'percent_corner_3s_of_3pa': 'percent_of_corner_3_pointers_in_3_point_attempts',
    'corner_3_point_percent': 'corner_3_point_percentage',
    'num_heaves_attempted': 'number_of_heaves_attempted',
    'num_heaves_made': 'number_of_heaves_made'
}

player_shoot.rename(columns=new_names, inplace=True)
player_shoot = player_shoot.drop(['birth_year'], axis='columns')
player_shoot = player_shoot[player_shoot.team != 'TOT']
player_shoot = player_shoot.drop(['age'], axis='columns')
player_shoot = player_shoot.dropna(subset=['field_goal_percentage', 'average_field_goal_attempt_distance', 'percentage_of_field_goal_attempts_from_2_point_range', 'percentage_of_field_goal_attempts_from_0_to_3_feet', 'percentage_of_field_goal_attempts_from_3_to_10_feet', 'percentage_of_field_goal_attempts_from_10_to_16_feet', 'percentage_of_field_goal_attempts_from_16_feet_to_3_point_range', 'percentage_of_field_goal_attempts_from_3_point_range', 'field_goal_percentage_from_2_point_range', 'field_goal_percentage_from_0_to_3_feet', 'field_goal_percentage_from_3_to_10_feet', 'field_goal_percentage_from_10_to_16_feet', 'field_goal_percentage_from_16_feet_to_3_point_range', 'three_point_percentage', 'percent_assisted_two_point_field_goal', 'percent_assisted_three_point_field_goal', 'percent_of_dunks_in_field_goal_attempts', 'percent_of_corner_3_pointers_in_3_point_attempts', 'corner_3_point_percentage'])  
player_shoot.to_csv('data/processed/player_shooting_cleaned.csv', index=False)

# %%
new_names = {
    'seas_id': 'season_id',
    'player': 'player_name',
    'pos': 'position',
    'age': 'player_age',
    'experience': 'years_of_experience',
    'lg': 'league',
    'tm': 'team',
    'g': 'games_played',
    'mp': 'minutes_played',
    'per': 'player_efficiency_rating',
    'ts_percent': 'true_shooting_percentage',
    'x3p_ar': 'three_point_attempt_rate',
    'f_tr': 'free_throw_attempt_rate',
    'orb_percent': 'offensive_rebound_percentage',
    'drb_percent': 'defensive_rebound_percentage',
    'trb_percent': 'total_rebound_percentage',
    'ast_percent': 'assist_percentage',
    'stl_percent': 'steal_percentage',
    'blk_percent': 'block_percentage',
    'tov_percent': 'turnover_percentage',
    'usg_percent': 'usage_percentage',
    'ows': 'offensive_win_shares',
    'dws': 'defensive_win_shares',
    'ws': 'win_shares',
    'ws_48': 'win_shares_per_48_minutes',
    'obpm': 'offensive_box_plus_minus',
    'dbpm': 'defensive_box_plus_minus',
    'bpm': 'box_plus_minus',
    'vorp': 'value_over_replacement_player'
}

adv_st = adv_st.rename(columns=new_names)
adv_st = adv_st[adv_st.team != 'TOT']
adv_st = adv_st[adv_st.season >= 1980]
adv_st = adv_st[adv_st.league == 'NBA']
adv_st = adv_st.dropna(subset=['true_shooting_percentage', 'three_point_attempt_rate', 'free_throw_attempt_rate'])
adv_st.to_csv('data/processed/advanced_cleaned.csv', index=False)

# %%
new_names = {
    'seas_id': 'season_id',
    'player': 'player_name',
    'pos': 'position',
    'age': 'player_age',
    'experience': 'years_of_experience',
    'lg': 'league',
    'tm': 'team',
    'g': 'games_played',
    'gs': 'games_started',
    'mp': 'minutes_played',
    'fg': 'field_goals',
    'fga': 'field_goal_attempts',
    'fg_percent': 'field_goal_percentage',
    'x3p': 'three_pointers',
    'x3pa': 'three_point_attempts',
    'x3p_percent': 'three_point_percentage',
    'x2p': 'two_pointers',
    'x2pa': 'two_point_attempts',
    'x2p_percent': 'two_point_percentage',
    'e_fg_percent': 'effective_field_goal_percentage',
    'ft': 'free_throws',
    'fta': 'free_throw_attempts',
    'ft_percent': 'free_throw_percentage',
    'orb': 'offensive_rebounds',
    'drb': 'defensive_rebounds',
    'trb': 'total_rebounds',
    'ast': 'assists',
    'stl': 'steals',
    'blk': 'blocks',
    'tov': 'turnovers',
    'pf': 'personal_fouls',
    'pts': 'points'
}
player_tot = player_tot.rename(columns=new_names)
player_tot = player_tot[player_tot.season >= 1980]
player_tot = player_tot[player_tot.team != 'TOT']
player_tot = player_tot.dropna(subset=['field_goal_percentage', 'three_point_percentage', 'two_point_percentage', 'effective_field_goal_percentage', 'free_throw_percentage']) 
player_tot.to_csv('data/processed/player_totals_cleaned.csv', index=False)

# %%
new_names = {
    'seas': 'season',
    'lg': 'league',
    'team': 'team',
    'abbreviation': 'team_abbreviation',
    'playoffs': 'playoffs',
    'g': 'games_played',
    'mp': 'minutes_played',
    'fg': 'field_goals',
    'fga': 'field_goal_attempts',
    'fg_percent': 'field_goal_percentage',
    'x3p': 'three_pointers',
    'x3pa': 'three_point_attempts',
    'x3p_percent': 'three_point_percentage',
    'x2p': 'two_pointers',
    'x2pa': 'two_point_attempts',
    'x2p_percent': 'two_point_percentage',
    'ft': 'free_throws',
    'fta': 'free_throw_attempts',
    'ft_percent': 'free_throw_percentage',
    'orb': 'offensive_rebounds',
    'drb': 'defensive_rebounds',
    'trb': 'total_rebounds',
    'ast': 'assists',
    'stl': 'steals',
    'blk': 'blocks',
    'tov': 'turnovers',
    'pf': 'personal_fouls',
    'pts': 'points'
}
team_tot = team_tot.rename(columns=new_names)
team_tot = team_tot[team_tot.season >= 1980]
team_tot = team_tot.dropna(subset=['team_abbreviation'])
team_tot.to_csv('data/processed/team_totals_cleaned.csv', index=False)

# %%
new_names = {
    'seas_id': 'season_id',
    'player': 'player_name',
    'birth_year': 'year_of_birth',
    'pos': 'position',
    'age': 'player_age',
    'experience': 'years_of_experience',
    'lg': 'league',
    'tm': 'team',
    'g': 'games_played',
    'gs': 'games_started',
    'mp_per_game': 'minutes_played_per_game',
    'fg_per_game': 'field_goals_per_game',
    'fga_per_game': 'field_goal_attempts_per_game',
    'fg_percent': 'field_goal_percentage',
    'x3p_per_game': 'three_pointers_per_game',
    'x3pa_per_game': 'three_point_attempts_per_game',
    'x3p_percent': 'three_point_percentage',
    'x2p_per_game': 'two_pointers_per_game',
    'x2pa_per_game': 'two_point_attempts_per_game',
    'x2p_percent': 'two_point_percentage',
    'e_fg_percent': 'effective_field_goal_percentage',
    'ft_per_game': 'free_throws_per_game',
    'fta_per_game': 'free_throw_attempts_per_game',
    'ft_percent': 'free_throw_percentage',
    'orb_per_game': 'offensive_rebounds_per_game',
    'drb_per_game': 'defensive_rebounds_per_game',
    'trb_per_game': 'total_rebounds_per_game',
    'ast_per_game': 'assists_per_game',
    'stl_per_game': 'steals_per_game',
    'blk_per_game': 'blocks_per_game',
    'tov_per_game': 'turnovers_per_game',
    'pf_per_game': 'personal_fouls_per_game',
    'pts_per_game': 'points_per_game'
}
player_pg = player_pg.rename(columns=new_names)
player_pg = player_pg[player_pg.team != 'TOT']
player_pg = player_pg[player_pg.season >= 1980]
player_pg = player_pg[player_pg.league == 'NBA']
player_pg = player_pg.dropna(subset=['three_point_percentage', 'field_goal_percentage', 'two_point_percentage', 'effective_field_goal_percentage', 'free_throw_percentage'])
player_pg.to_csv('data/processed/player_per_game_cleaned.csv', index=False)

# %%
advanced = pd.read_csv('data/processed/advanced_cleaned.csv')
per_game = pd.read_csv('data/processed/player_per_game_cleaned.csv')
shooting = pd.read_csv('data/processed/player_shooting_cleaned.csv')
player_totals = pd.read_csv('data/processed/player_totals_cleaned.csv')
team_totals = pd.read_csv('data/processed/team_totals_cleaned.csv')
merged = pd.merge(pd.merge(pd.merge(advanced, per_game, on=['season_id', 'player_id']),shooting, on=['season_id', 'player_id']), player_totals, on=['season_id', 'player_id'])

#Drop unnecessary columns
merged.drop(['season_y', 'player_name_y','position_y', 'years_of_experience_y', 'league_x', 'league_y', 'games_played_y', 'team_y', 'minutes_played_x', 'minutes_played_y', 'free_throw_percentage_y', 'field_goal_percentage_y', 'three_point_percentage_y', 'two_point_percentage_y', 'effective_field_goal_percentage_y', 'free_throw_percentage_y'], axis=1, inplace=True)

#Rename columns
merged.rename(columns={'season_x': 'season', 'player_name_x': 'player_name', 'position_x': 'position', 'years_of_experience_x': 'years_of_experience', 'games_played_x': 'games_played', 'team_x': 'team', 'free_throw_percentage_y': 'free_throw_percentage', 'field_goal_percentage_x': 'field_goal_percentage', 'three_point_percentage_x': 'three_point_percentage', 'two_point_percentage_x': 'two_point_percentage', 'effective_field_goal_percentage_x': 'effective_field_goal_percentage', 'free_throw_percentage_x': 'free_throw_percentage'}, inplace=True)

#Drop duplicate columns 
merged = merged.T.groupby(level=0).first().T

#Reorder columns
merged = merged[['season_id', 'season', 'player_id', 'player_name', 'position', 'years_of_experience', 'team', 'games_played', 'minutes_played', 'minutes_played_per_game', 'field_goals_per_game', 'field_goal_attempts_per_game', 'field_goal_percentage', 'three_pointers_per_game', 'three_point_attempts_per_game', 'three_point_percentage', 'two_pointers_per_game', 'two_point_attempts_per_game', 'two_point_percentage', 'effective_field_goal_percentage', 'free_throws_per_game', 'free_throw_attempts_per_game', 'free_throw_percentage', 'offensive_rebounds_per_game', 'defensive_rebounds_per_game', 'total_rebounds_per_game', 'assists_per_game', 'steals_per_game', 'blocks_per_game', 'turnovers_per_game', 'personal_fouls_per_game', 'points_per_game', 'field_goals', 'field_goal_attempts', 'three_pointers', 'three_point_attempts', 'two_pointers', 'two_point_attempts', 'free_throws', 'free_throw_attempts', 'offensive_rebounds', 'defensive_rebounds', 'total_rebounds', 'assists', 'steals', 'blocks', 'turnovers', 'personal_fouls', 'points', 'player_efficiency_rating', 'true_shooting_percentage', 'three_point_attempt_rate', 'free_throw_attempt_rate', 'offensive_rebound_percentage', 'defensive_rebound_percentage', 'total_rebound_percentage', 'assist_percentage', 'steal_percentage', 'block_percentage', 'turnover_percentage', 'usage_percentage', 'offensive_win_shares', 'defensive_win_shares', 'win_shares', 'win_shares_per_48_minutes', 'offensive_box_plus_minus', 'defensive_box_plus_minus', 'box_plus_minus', 'average_field_goal_attempt_distance', 'percentage_of_field_goal_attempts_from_2_point_range', 'percentage_of_field_goal_attempts_from_0_to_3_feet', 'percentage_of_field_goal_attempts_from_3_to_10_feet', 'percentage_of_field_goal_attempts_from_10_to_16_feet', 'percentage_of_field_goal_attempts_from_16_feet_to_3_point_range', 'percentage_of_field_goal_attempts_from_3_point_range', 'field_goal_percentage_from_2_point_range', 'field_goal_percentage_from_0_to_3_feet', 'field_goal_percentage_from_3_to_10_feet', 'field_goal_percentage_from_10_to_16_feet', 'field_goal_percentage_from_16_feet_to_3_point_range', 'percent_assisted_two_point_field_goal', 'percent_assisted_three_point_field_goal', 'percent_of_dunks_in_field_goal_attempts', 'number_of_dunks', 'percent_of_corner_3_pointers_in_3_point_attempts', 'corner_3_point_percentage', 'number_of_heaves_attempted', 'number_of_heaves_made']]

#Save the cleaned dataset
merged.to_csv('data/processed/merged_cleaned.csv', index=False)
# Out:
# C:\Users\tateb\AppData\Local\Temp\ipykernel_7064\4042636772.py:6: FutureWarning: Passing 'suffixes' which cause duplicate columns {'team_x', 'games_played_x', 'league_x', 'years_of_experience_x', 'player_name_x', 'position_x', 'season_x'} in the result is deprecated and will raise a MergeError in a future version.
#   merged = pd.merge(pd.merge(pd.merge(advanced, per_game, on=['season_id', 'player_id']),shooting, on=['season_id', 'player_id']), player_totals, on=['season_id', 'player_id'])
