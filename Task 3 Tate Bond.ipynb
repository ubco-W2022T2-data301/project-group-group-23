# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_theme(style="ticks", font_scale=1.3)
plt.rc("axes.spines", top=False, right=False)

# %% [markdown]
# # **Topic 2**
# **

# %%
df = pd.read_csv("data/raw/Advanced.csv", index_col=[0])
df
# Out:
#          season  player_id          player  birth_year  pos   age  experience  \
# seas_id
# 30458      2023       5025      A.J. Green         NaN   SG  23.0           1
# 30459      2023       5026     A.J. Lawson         NaN   SG  22.0           1
# 30460      2023       5026     A.J. Lawson         NaN   SG  22.0           1
# 30461      2023       5026     A.J. Lawson         NaN   SG  22.0           1
# 30462      2023       4219    Aaron Gordon         NaN   PF  27.0           9
# ...         ...        ...             ...         ...  ...   ...         ...
# 200        1947        157     Walt Miller         NaN    F  31.0           1
# 201        1947        158   Warren Fenley         NaN    F  24.0           1
# 202        1947        159   Wilbert Kautz         NaN  G-F  31.0           1
# 203        1947        160  Woody Grimshaw         NaN    G  27.0           1
# 204        1947        161     Wyndol Gray         NaN  G-F  24.0           1
#
# ...
